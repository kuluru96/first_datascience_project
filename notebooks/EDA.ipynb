# %%
  import numpy as np
  import pandas as pd
  import matplotlib.pyplot as plt
  import seaborn as sns
  import os

# %%
raw_data_path =  os.path.join(os.path.pardir,'data', 'raw')
train_data_path =  os.path.join(raw_data_path,'train.csv')
test_data_path =  os.path.join(raw_data_path,'test.csv')

# %%
train_df = pd.read_csv(train_data_path, index_col="PassengerId")
test_df = pd.read_csv(test_data_path, index_col="PassengerId")

# %%
  type(train_df)
# Out:
# pandas.core.frame.DataFrame

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 892 to 1309
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    418 non-null    int64
#  1   Name      418 non-null    object
#  2   Sex       418 non-null    object
#  3   Age       332 non-null    float64
#  4   SibSp     418 non-null    int64
#  5   Parch     418 non-null    int64
#  6   Ticket    418 non-null    object
#  7   Fare      417 non-null    float64
#  8   Cabin     91 non-null     object
#  9   Embarked  418 non-null    object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 35.9+ KB

# %%
test_df['Survived'] = -888

# %%
df = pd.concat([train_df, test_df], axis=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  1309 non-null   int64
#  1   Pclass    1309 non-null   int64
#  2   Name      1309 non-null   object
#  3   Sex       1309 non-null   object
#  4   Age       1046 non-null   float64
#  5   SibSp     1309 non-null   int64
#  6   Parch     1309 non-null   int64
#  7   Ticket    1309 non-null   object
#  8   Fare      1308 non-null   float64
#  9   Cabin     295 non-null    object
#  10  Embarked  1307 non-null   object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 122.7+ KB

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#              Survived  Pclass                          Name     Sex   Age  \
# PassengerId
# 1305             -888       3            Spector, Mr. Woolf    male   NaN
# 1306             -888       1  Oliva y Ocana, Dona. Fermina  female  39.0
# 1307             -888       3  Saether, Mr. Simon Sivertsen    male  38.5
# 1308             -888       3           Ware, Mr. Frederick    male   NaN
# 1309             -888       3      Peter, Master. Michael J    male   NaN
#
#              SibSp  Parch              Ticket      Fare Cabin Embarked
# PassengerId
# 1305             0      0           A.5. 3236    8.0500   NaN        S
# 1306             0      0            PC 17758  108.9000  C105        C
# 1307             0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1308             0      0              359309    8.0500   NaN        S
# 1309             1      1                2668   22.3583   NaN        C

# %%
df.Name
# Out:
# PassengerId
# 1                                 Braund, Mr. Owen Harris
# 2       Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                                  Heikkinen, Miss. Laina
# 4            Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                                Allen, Mr. William Henry
#                               ...
# 1305                                   Spector, Mr. Woolf
# 1306                         Oliva y Ocana, Dona. Fermina
# 1307                         Saether, Mr. Simon Sivertsen
# 1308                                  Ware, Mr. Frederick
# 1309                             Peter, Master. Michael J
# Name: Name, Length: 1309, dtype: object

# %%
df[['Name','Age']]
# Out:
#                                                           Name   Age
# PassengerId
# 1                                      Braund, Mr. Owen Harris  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 3                                       Heikkinen, Miss. Laina  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 5                                     Allen, Mr. William Henry  35.0
# ...                                                        ...   ...
# 1305                                        Spector, Mr. Woolf   NaN
# 1306                              Oliva y Ocana, Dona. Fermina  39.0
# 1307                              Saether, Mr. Simon Sivertsen  38.5
# 1308                                       Ware, Mr. Frederick   NaN
# 1309                                  Peter, Master. Michael J   NaN
#
# [1309 rows x 2 columns]

# %%
df.loc[5:10,]
# Out:
#              Survived  Pclass  \
# PassengerId
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 8                               Palsson, Master. Gosta Leonard    male   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
#
#              SibSp  Parch  Ticket     Fare Cabin Embarked
# PassengerId
# 5                0      0  373450   8.0500   NaN        S
# 6                0      0  330877   8.4583   NaN        Q
# 7                0      0   17463  51.8625   E46        S
# 8                3      1  349909  21.0750   NaN        S
# 9                0      2  347742  11.1333   NaN        S
# 10               1      0  237736  30.0708   NaN        C

# %%
df.loc[5:10,['Survived','Fare']]
# Out:
#              Survived     Fare
# PassengerId
# 5                   0   8.0500
# 6                   0   8.4583
# 7                   0  51.8625
# 8                   0  21.0750
# 9                   1  11.1333
# 10                  1  30.0708

# %%
df.iloc[5:10,3:8]
# Out:
#                 Sex   Age  SibSp  Parch  Ticket
# PassengerId
# 6              male   NaN      0      0  330877
# 7              male  54.0      0      0   17463
# 8              male   2.0      3      1  349909
# 9            female  27.0      0      2  347742
# 10           female  14.0      1      0  237736

# %%
first_class_pass = df.loc[df.Pclass == 1]
print("No of first calss passengers : {0}" .format(len(first_class_pass)))
# Out:
# No of first calss passengers : 323

# %%
df.describe()
# Out:
#           Survived       Pclass          Age        SibSp        Parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean   -283.301757     2.294882    29.881138     0.498854     0.385027
# std     414.337413     0.837836    14.413493     1.041658     0.865560
# min    -888.000000     1.000000     0.170000     0.000000     0.000000
# 25%    -888.000000     2.000000    21.000000     0.000000     0.000000
# 50%       0.000000     3.000000    28.000000     0.000000     0.000000
# 75%       1.000000     3.000000    39.000000     1.000000     0.000000
# max       1.000000     3.000000    80.000000     8.000000     9.000000
#
#               Fare
# count  1308.000000
# mean     33.295479
# std      51.758668
# min       0.000000
# 25%       7.895800
# 50%      14.454200
# 75%      31.275000
# max     512.329200

# %%
print('Mean of Age ; {0}'.format(df.Age.mean()))
print('Median of Age ; {0}'.format(df.Age.median()))
# Out:
# Mean of Age ; 29.881137667304014
# Median of Age ; 28.0

# %%
df.Age.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df.describe(include='all')
# Out:
#            Survived       Pclass                  Name   Sex          Age  \
# count   1309.000000  1309.000000                  1309  1309  1046.000000
# unique          NaN          NaN                  1307     2          NaN
# top             NaN          NaN  Connolly, Miss. Kate  male          NaN
# freq            NaN          NaN                     2   843          NaN
# mean    -283.301757     2.294882                   NaN   NaN    29.881138
# std      414.337413     0.837836                   NaN   NaN    14.413493
# min     -888.000000     1.000000                   NaN   NaN     0.170000
# 25%     -888.000000     2.000000                   NaN   NaN    21.000000
# 50%        0.000000     3.000000                   NaN   NaN    28.000000
# 75%        1.000000     3.000000                   NaN   NaN    39.000000
# max        1.000000     3.000000                   NaN   NaN    80.000000
#
#               SibSp        Parch    Ticket         Fare        Cabin Embarked
# count   1309.000000  1309.000000      1309  1308.000000          295     1307
# unique          NaN          NaN       929          NaN          186        3
# top             NaN          NaN  CA. 2343          NaN  C23 C25 C27        S
# freq            NaN          NaN        11          NaN            6      914
# mean       0.498854     0.385027       NaN    33.295479          NaN      NaN
# std        1.041658     0.865560       NaN    51.758668          NaN      NaN
# min        0.000000     0.000000       NaN     0.000000          NaN      NaN
# 25%        0.000000     0.000000       NaN     7.895800          NaN      NaN
# 50%        0.000000     0.000000       NaN    14.454200          NaN      NaN
# 75%        1.000000     0.000000       NaN    31.275000          NaN      NaN
# max        8.000000     9.000000       NaN   512.329200          NaN      NaN

# %%
df.Pclass.value_counts().plot(kind='bar', rot=0, title='Calss wise passengers');

# %%
df.Sex.value_counts(normalize='true')
# Out:
# male      0.644003
# female    0.355997
# Name: Sex, dtype: float64

# %%
df.Age.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.Age.plot(kind = 'kde', title='KDE for AGE')
# Out:
# <AxesSubplot:title={'center':'KDE for AGE'}, ylabel='Density'>

# %%
df.Fare.plot(kind ='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.Fare.skew()
df.Age.skew()
# Out:
# 0.40767455974362266

# %%
plt.hist(df.Fare)
# Out:
# (array([1070.,  154.,   42.,    4.,   21.,   13.,    0.,    0.,    0.,
#            4.]),
#  array([  0.     ,  51.23292, 102.46584, 153.69876, 204.93168, 256.1646 ,
#         307.39752, 358.63044, 409.86336, 461.09628, 512.3292 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.kdeplot(df.Age)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
corr = df.corr()
corr.style.background_gradient(cmap = 'coolwarm').set_precision(3)
# Out:
# <style  type="text/css" >
# #T_c8c39282_6b01_11eb_a17c_405bd8297d39row0_col0,#T_c8c39282_6b01_11eb_a17c_405bd8297d39row1_col1,#T_c8c39282_6b01_11eb_a17c_405bd8297d39row2_col2,#T_c8c39282_6b01_11eb_a17c_405bd8297d39row3_col3,#T_c8c39282_6b01_11eb_a17c_405bd8297d39row4_col4,#T_c8c39282_6b01_11eb_a17c_405bd8297d39row5_col5{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_c8c39282_6b01_11eb_a17c_405bd8297d39row0_col1{
#             background-color:  #b7cff9;
#             color:  #000000;
#         }#T_c8c39282_6b01_11eb_a17c_405bd8297d39row0_col2{
#             background-color:  #96b7ff;
#             color:  #000000;
#         }#T_c8c39282_6b01_11eb_a17c_405bd8297d39row0_col3{
#             background-color:  #84a7fc;
#             color:  #000000;
#         }#T_c8c39282_6b01_11eb_a17c_405bd8297d39row0_col4{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_c8c39282_6b01_11eb_a17c_405bd8297d39row0_col5{
#             background-color:  #abc8fd;
#             color:  #000000;
#         }#T_c8c39282_6b01_11eb_a17c_405bd8297d39row1_col0{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_c8c39282_6b01_11eb_a17c_405bd8297d39row1_col2,#T_c8c39282_6b01_11eb_a17c_405bd8297d39row1_col5,#T_c8c39282_6b01_11eb_a17c_405bd8297d39row2_col3,#T_c8c39282_6b01_11eb_a17c_405bd8297d39row2_col4,#T_c8c39282_6b01_11eb_a17c_405bd8297d39row5_col0,#T_c8c39282_6b01_11eb_a17c_405bd8297d39row5_col1{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_c8c39282_6b01_11eb_a17c_405bd8297d39row1_col3{
#             background-color:  #8badfd;
#             color:  #000000;
#         }#T_c8c39282_6b01_11eb_a17c_405bd8297d39row1_col4{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_c8c39282_6b01_11eb_a17c_405bd8297d39row2_col0{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_c8c39282_6b01_11eb_a17c_405bd8297d39row2_col1{
#             background-color:  #5875e1;
#             color:  #000000;
#         }#T_c8c39282_6b01_11eb_a17c_405bd8297d39row2_col5{
#             background-color:  #d6dce4;
#             color:  #000000;
#         }#T_c8c39282_6b01_11eb_a17c_405bd8297d39row3_col0{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_c8c39282_6b01_11eb_a17c_405bd8297d39row3_col1{
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }#T_c8c39282_6b01_11eb_a17c_405bd8297d39row3_col2{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_c8c39282_6b01_11eb_a17c_405bd8297d39row3_col4{
#             background-color:  #d1dae9;
#             color:  #000000;
#         }#T_c8c39282_6b01_11eb_a17c_405bd8297d39row3_col5{
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }#T_c8c39282_6b01_11eb_a17c_405bd8297d39row4_col0{
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }#T_c8c39282_6b01_11eb_a17c_405bd8297d39row4_col1{
#             background-color:  #b6cefa;
#             color:  #000000;
#         }#T_c8c39282_6b01_11eb_a17c_405bd8297d39row4_col2{
#             background-color:  #7597f6;
#             color:  #000000;
#         }#T_c8c39282_6b01_11eb_a17c_405bd8297d39row4_col3{
#             background-color:  #dcdddd;
#             color:  #000000;
#         }#T_c8c39282_6b01_11eb_a17c_405bd8297d39row4_col5{
#             background-color:  #dddcdc;
#             color:  #000000;
#         }#T_c8c39282_6b01_11eb_a17c_405bd8297d39row5_col2{
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }#T_c8c39282_6b01_11eb_a17c_405bd8297d39row5_col3{
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }#T_c8c39282_6b01_11eb_a17c_405bd8297d39row5_col4{
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }</style><table id="T_c8c39282_6b01_11eb_a17c_405bd8297d39" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Survived</th>        <th class="col_heading level0 col1" >Pclass</th>        <th class="col_heading level0 col2" >Age</th>        <th class="col_heading level0 col3" >SibSp</th>        <th class="col_heading level0 col4" >Parch</th>        <th class="col_heading level0 col5" >Fare</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c8c39282_6b01_11eb_a17c_405bd8297d39level0_row0" class="row_heading level0 row0" >Survived</th>
#                         <td id="T_c8c39282_6b01_11eb_a17c_405bd8297d39row0_col0" class="data row0 col0" >1.000</td>
#                         <td id="T_c8c39282_6b01_11eb_a17c_405bd8297d39row0_col1" class="data row0 col1" >0.024</td>
#                         <td id="T_c8c39282_6b01_11eb_a17c_405bd8297d39row0_col2" class="data row0 col2" >-0.019</td>
#                         <td id="T_c8c39282_6b01_11eb_a17c_405bd8297d39row0_col3" class="data row0 col3" >0.034</td>
#                         <td id="T_c8c39282_6b01_11eb_a17c_405bd8297d39row0_col4" class="data row0 col4" >-0.006</td>
#                         <td id="T_c8c39282_6b01_11eb_a17c_405bd8297d39row0_col5" class="data row0 col5" >-0.031</td>
#             </tr>
#             <tr>
#                         <th id="T_c8c39282_6b01_11eb_a17c_405bd8297d39level0_row1" class="row_heading level0 row1" >Pclass</th>
#                         <td id="T_c8c39282_6b01_11eb_a17c_405bd8297d39row1_col0" class="data row1 col0" >0.024</td>
#                         <td id="T_c8c39282_6b01_11eb_a17c_405bd8297d39row1_col1" class="data row1 col1" >1.000</td>
#                         <td id="T_c8c39282_6b01_11eb_a17c_405bd8297d39row1_col2" class="data row1 col2" >-0.408</td>
#                         <td id="T_c8c39282_6b01_11eb_a17c_405bd8297d39row1_col3" class="data row1 col3" >0.061</td>
#                         <td id="T_c8c39282_6b01_11eb_a17c_405bd8297d39row1_col4" class="data row1 col4" >0.018</td>
#                         <td id="T_c8c39282_6b01_11eb_a17c_405bd8297d39row1_col5" class="data row1 col5" >-0.559</td>
#             </tr>
#             <tr>
#                         <th id="T_c8c39282_6b01_11eb_a17c_405bd8297d39level0_row2" class="row_heading level0 row2" >Age</th>
#                         <td id="T_c8c39282_6b01_11eb_a17c_405bd8297d39row2_col0" class="data row2 col0" >-0.019</td>
#                         <td id="T_c8c39282_6b01_11eb_a17c_405bd8297d39row2_col1" class="data row2 col1" >-0.408</td>
#                         <td id="T_c8c39282_6b01_11eb_a17c_405bd8297d39row2_col2" class="data row2 col2" >1.000</td>
#                         <td id="T_c8c39282_6b01_11eb_a17c_405bd8297d39row2_col3" class="data row2 col3" >-0.244</td>
#                         <td id="T_c8c39282_6b01_11eb_a17c_405bd8297d39row2_col4" class="data row2 col4" >-0.151</td>
#                         <td id="T_c8c39282_6b01_11eb_a17c_405bd8297d39row2_col5" class="data row2 col5" >0.179</td>
#             </tr>
#             <tr>
#                         <th id="T_c8c39282_6b01_11eb_a17c_405bd8297d39level0_row3" class="row_heading level0 row3" >SibSp</th>
#                         <td id="T_c8c39282_6b01_11eb_a17c_405bd8297d39row3_col0" class="data row3 col0" >0.034</td>
#                         <td id="T_c8c39282_6b01_11eb_a17c_405bd8297d39row3_col1" class="data row3 col1" >0.061</td>
#                         <td id="T_c8c39282_6b01_11eb_a17c_405bd8297d39row3_col2" class="data row3 col2" >-0.244</td>
#                         <td id="T_c8c39282_6b01_11eb_a17c_405bd8297d39row3_col3" class="data row3 col3" >1.000</td>
#                         <td id="T_c8c39282_6b01_11eb_a17c_405bd8297d39row3_col4" class="data row3 col4" >0.374</td>
#                         <td id="T_c8c39282_6b01_11eb_a17c_405bd8297d39row3_col5" class="data row3 col5" >0.160</td>
#             </tr>
#             <tr>
#                         <th id="T_c8c39282_6b01_11eb_a17c_405bd8297d39level0_row4" class="row_heading level0 row4" >Parch</th>
#                         <td id="T_c8c39282_6b01_11eb_a17c_405bd8297d39row4_col0" class="data r

# %%
plt.scatter(df.Pclass, df.Fare, alpha = 0.2)
plt.title('Age Vs Fare')
plt.xlabel('Age')
plt.show()

# %%
 df.groupby('Sex').Age.median()
# Out:
# Sex
# female    27.0
# male      28.0
# Name: Age, dtype: float64

# %%
df.groupby(['Pclass'])['Fare','Age'].median()
# Out:
#            Fare   Age
# Pclass
# 1       60.0000  39.0
# 2       15.0458  29.0
# 3        8.0500  24.0

# %%
df.groupby(['Pclass']).agg({'Fare':'mean','Age':'median'})
# Out:
#              Fare   Age
# Pclass
# 1       87.508992  39.0
# 2       21.179196  29.0
# 3       13.302889  24.0

# %%
pd.crosstab(df.Sex,df.Pclass).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Sex'>

# %%
df.pivot_table(index='Sex', columns='Pclass', values = 'Age', aggfunc='mean')
# Out:
# Pclass          1          2          3
# Sex
# female  37.037594  27.499223  22.185329
# male    41.029272  30.815380  25.962264

# %%
df.groupby(['Sex','Pclass']).Age.mean().unstack()
# Out:
# Pclass          1          2          3
# Sex
# female  37.037594  27.499223  22.185329
# male    41.029272  30.815380  25.962264

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  1309 non-null   int64
#  1   Pclass    1309 non-null   int64
#  2   Name      1309 non-null   object
#  3   Sex       1309 non-null   object
#  4   Age       1046 non-null   float64
#  5   SibSp     1309 non-null   int64
#  6   Parch     1309 non-null   int64
#  7   Ticket    1309 non-null   object
#  8   Fare      1308 non-null   float64
#  9   Cabin     295 non-null    object
#  10  Embarked  1307 non-null   object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 162.7+ KB

# %%
df[df.Embarked.isnull()]
# Out:
#              Survived  Pclass                                       Name  \
# PassengerId
# 62                  1       1                        Icard, Miss. Amelie
# 830                 1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#                 Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# PassengerId
# 62           female  38.0      0      0  113572  80.0   B28      NaN
# 830          female  62.0      0      0  113572  80.0   B28      NaN

# %%
df.Embarked.value_counts()
# Out:
# S    914
# C    270
# Q    123
# Name: Embarked, dtype: int64

# %%
pd.crosstab(df[df.Survived != -888].Survived,df[df.Survived != -888].Embarked)
# Out:
# Embarked   C   Q    S
# Survived
# 0         75  47  427
# 1         93  30  217

# %%
#df.Embarked.fillna('S', inplace=True)

# %%
df.groupby(['Pclass','Embarked']).Fare.median().unstack()
# Out:
# Embarked        C      Q       S
# Pclass
# 1         76.7292  90.00  52.000
# 2         15.3146  12.35  15.375
# 3          7.8958   7.75   8.050

# %%
df.Embarked.fillna('C', inplace=True)

# %%
df[df.Embarked.isnull()]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Fare.isnull()]
# Out:
#              Survived  Pclass                Name   Sex   Age  SibSp  Parch  \
# PassengerId
# 1044             -888       3  Storey, Mr. Thomas  male  60.5      0      0
#
#             Ticket  Fare Cabin Embarked
# PassengerId
# 1044          3701   NaN   NaN        S

# %%
median_fare = df.loc[(df.Pclass==3)&(df.Embarked=='S'),'Fare'].median()
print(median_fare)
# Out:
# 8.05

# %%
df.Fare.fillna(median_fare, inplace=True)

# %%
df[df.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Age.isnull()]
# Out:
#              Survived  Pclass                             Name     Sex  Age  \
# PassengerId
# 6                   0       3                 Moran, Mr. James    male  NaN
# 18                  1       2     Williams, Mr. Charles Eugene    male  NaN
# 20                  1       3          Masselmani, Mrs. Fatima  female  NaN
# 27                  0       3          Emir, Mr. Farred Chehab    male  NaN
# 29                  1       3    O'Dwyer, Miss. Ellen "Nellie"  female  NaN
# ...               ...     ...                              ...     ...  ...
# 1300             -888       3  Riordan, Miss. Johanna Hannah""  female  NaN
# 1302             -888       3           Naughton, Miss. Hannah  female  NaN
# 1305             -888       3               Spector, Mr. Woolf    male  NaN
# 1308             -888       3              Ware, Mr. Frederick    male  NaN
# 1309             -888       3         Peter, Master. Michael J    male  NaN
#
#              SibSp  Parch     Ticket     Fare Cabin Embarked
# PassengerId
# 6                0      0     330877   8.4583   NaN        Q
# 18               0      0     244373  13.0000   NaN        S
# 20               0      0       2649   7.2250   NaN        C
# 27               0      0       2631   7.2250   NaN        C
# 29               0      0     330959   7.8792   NaN        Q
# ...            ...    ...        ...      ...   ...      ...
# 1300             0      0     334915   7.7208   NaN        Q
# 1302             0      0     365237   7.7500   NaN        Q
# 1305             0      0  A.5. 3236   8.0500   NaN        S
# 1308             0      0     359309   8.0500   NaN        S
# 1309             1      1       2668  22.3583   NaN        C
#
# [263 rows x 11 columns]

# %%
df.Age.plot(kind='hist', bins=20);

# %%
df.groupby('Sex').Age.median()
# Out:
# Sex
# female    27.0
# male      28.0
# Name: Age, dtype: float64

# %%
df[df.Age.notnull()].boxplot('Age','Pclass')
# Out:
# <AxesSubplot:title={'center':'Age'}, xlabel='Pclass'>

# %%
df.Name
# Out:
# PassengerId
# 1                                 Braund, Mr. Owen Harris
# 2       Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                                  Heikkinen, Miss. Laina
# 4            Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                                Allen, Mr. William Henry
#                               ...
# 1305                                   Spector, Mr. Woolf
# 1306                         Oliva y Ocana, Dona. Fermina
# 1307                         Saether, Mr. Simon Sivertsen
# 1308                                  Ware, Mr. Frederick
# 1309                             Peter, Master. Michael J
# Name: Name, Length: 1309, dtype: object

# %%
def NameTitle(name):
    first_name_with_title = name.split(',')[1]
    title = first_name_with_title.split('.')[0]
    title = title.strip().lower()
    return title

# %%
df.Name.map(lambda x: NameTitle(x)).unique()
# Out:
# array(['mr', 'mrs', 'miss', 'master', 'don', 'rev', 'dr', 'mme', 'ms',
#        'major', 'lady', 'sir', 'mlle', 'col', 'capt', 'the countess',
#        'jonkheer', 'dona'], dtype=object)

# %%
def NameTitle(name):
    title_group = {'mr':'Mr',
                   'mrs' : 'Mrs',
                   'miss' : 'Miss',
                   'master' : 'Master',
                   'don' :'Sir',
                   'rev':'Sir',
                   'dr':'Officer',
                   'mme' :'Mrs',
                   'ms':'Mrs',
                   'major' :'Major',
                   'lady':'Lady',
                   'sir':'Sir',
                   'mlle':'Miss',
                   'col' : 'Officer',
                   'capt' :'Officer',
                   'the countess' : 'Lady',
                   'jonkheer' : 'Sir',
                   'dona':'Lady'
                    }
    first_name_with_title = name.split(',')[1]
    title = first_name_with_title.split('.')[0]
    title = title.strip().lower()
    return title_group[title]

# %%
df['Title'] = df.Name.map(lambda x: NameTitle(x))

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked Title
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S    Mr
# 2                1      0          PC 17599  71.2833   C85        C   Mrs
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S  Miss
# 4                1      0            113803  53.1000  C123        S   Mrs
# 5                0      0            373450   8.0500   NaN        S    Mr

# %%
df[df.Age.notnull()].boxplot('Age','Title')
# Out:
# <AxesSubplot:title={'center':'Age'}, xlabel='Title'>

# %%
title_age_median = df.groupby('Title').Age.transform('median')
df.Age.fillna(title_age_median, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  1309 non-null   int64
#  1   Pclass    1309 non-null   int64
#  2   Name      1309 non-null   object
#  3   Sex       1309 non-null   object
#  4   Age       1309 non-null   float64
#  5   SibSp     1309 non-null   int64
#  6   Parch     1309 non-null   int64
#  7   Ticket    1309 non-null   object
#  8   Fare      1309 non-null   float64
#  9   Cabin     295 non-null    object
#  10  Embarked  1309 non-null   object
#  11  Title     1309 non-null   object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 172.9+ KB

# %%
df.loc[df.Fare==df.Fare.max()]
# Out:
#              Survived  Pclass  \
# PassengerId
# 259                 1       1
# 680                 1       1
# 738                 1       1
# 1235             -888       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 259                                           Ward, Miss. Anna  female  35.0
# 680                         Cardeza, Mr. Thomas Drake Martinez    male  36.0
# 738                                     Lesurer, Mr. Gustave J    male  35.0
# 1235         Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0
#
#              SibSp  Parch    Ticket      Fare        Cabin Embarked Title
# PassengerId
# 259              0      0  PC 17755  512.3292          NaN        C  Miss
# 680              0      1  PC 17755  512.3292  B51 B53 B55        C    Mr
# 738              0      0  PC 17755  512.3292         B101        C    Mr
# 1235             0      1  PC 17755  512.3292  B51 B53 B55        C   Mrs

# %%
Log_fare = np.log(df.Fare + 1)

# %%
Log_fare.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['Fare_bin'] = pd.qcut(df.Fare,4, labels = ['very_low', 'low', 'high', 'very_high'])

# %%
df['Fare_bin'] = pd.qcut(df.Fare,4, labels = ['very_low', 'low', 'high', 'very_high']).value_counts().plot(kind= 'bar')

# %%
df['AgeState'] = np.where(df['Age'] >= 18, 'Adult', 'Child')

df['AgeState'].value_counts()
# Out:
# Adult    1147
# Child     162
# Name: AgeState, dtype: int64

# %%
pd.crosstab(df[df.Survived != -888].Survived, df[df.Survived != -888].AgeState)
# Out:
# AgeState  Adult  Child
# Survived
# 0           495     54
# 1           279     63

# %%
df['FamilySize'] = df.Parch + df.SibSp + 1

# %%
df['FamilySize'].plot(kind='hist#')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-442-48c1d6feefd0> in <module>
# ----> 1 df['FamilySize'].plot(kind='hist#')
#
# ~/.local/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     880
#     881         if kind not in self._all_kinds:
# --> 882             raise ValueError(f"{kind} is not a valid plot kind")
#     883
#     884         # The original data structured can be transformed before passed to the
#
# ValueError: hist# is not a valid plot kind

# %%
df.loc[df.FamilySize == df.FamilySize.max(),['Name','Survived','FamilySize','Ticket']]
# Out:
#                                           Name  Survived  FamilySize    Ticket
# PassengerId
# 160                 Sage, Master. Thomas Henry         0          11  CA. 2343
# 181               Sage, Miss. Constance Gladys         0          11  CA. 2343
# 202                        Sage, Mr. Frederick         0          11  CA. 2343
# 325                   Sage, Mr. George John Jr         0          11  CA. 2343
# 793                    Sage, Miss. Stella Anna         0          11  CA. 2343
# 847                   Sage, Mr. Douglas Bullen         0          11  CA. 2343
# 864          Sage, Miss. Dorothy Edith "Dolly"         0          11  CA. 2343
# 1080                           Sage, Miss. Ada      -888          11  CA. 2343
# 1234                     Sage, Mr. John George      -888          11  CA. 2343
# 1252               Sage, Master. William Henry      -888          11  CA. 2343
# 1257            Sage, Mrs. John (Annie Bullen)      -888          11  CA. 2343

# %%
pd.crosstab(df[df.Survived != -888].Survived, df[df.Survived != -888].FamilySize)
# Out:
# FamilySize   1   2   3   4   5   6   7   8   11
# Survived
# 0           374  72  43   8  12  19   8   6   7
# 1           163  89  59  21   3   3   4   0   0

# %%
df['IsMother'] = np.where(((df.Sex == 'female') & (df.Parch > 0) & (df.Age > 18) & (df.Title != 'Miss')), 1, 0)

# %%
pd.crosstab(df[df.Survived != -888].Survived, df[df.Survived != -888].IsMother)
# Out:
# IsMother    0   1
# Survived
# 0         533  16
# 1         303  39

# %%
df.Cabin.unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
#        'E58', 'C126', 'B71', 'B51 B53 B55', 'D49', 'B5', 'B20', 'F G63',
#        'C62 C64', 'E24', 'C90', 'C45', 'E8', 'B101', 'D45', 'C46', 'D30',
#        'E121', 'D11', 'E77', 'F38', 'B3', 'D6', 'B82 B84', 'D17', 'A36',
#        'B102', 'B69', 'E49', 'C47', 'D28', 'E17', 'A24', 'C50', 'B42',
#        'C148', 'B45', 'B36', 'A21', 'D34', 'A9', 'C31', 'B61', 'C53',
#        'D43', 'C130', 'C132', 'C55 C57', 'C116', 'F', 'A29', 'C6', 'C28',
#        'C51', 'C97', 'D22', 'B10', 'E45', 'E52', 'A11', 'B11', 'C80',
#        'C89', 'F E46', 'B26', 'F E57', 'A18', 'E60', 'E39 E41',
#        'B52 B54 B56', 'C39', 'B24', 'D40', 'D38', 'C105'], dtype=object)

# %%
df.loc[df.Cabin == 'T', 'Cabin'] = np.NaN

# %%
def get_deck(cabin):
    return np.where(pd.notnull(cabin),str(cabin)[0].upper(),'z')
df['Deck'] = df['Cabin'].map(lambda x: get_deck(x))

# %%
df.Deck.value_counts()
# Out:
# z    1015
# C      94
# B      65
# D      46
# E      41
# A      22
# F      21
# G       5
# Name: Deck, dtype: int64

# %%
pd.crosstab(df[df.Survived != -888].Survived, df[df.Survived != -888].Deck)
# Out:
# Deck      A   B   C   D   E  F  G    z
# Survived
# 0         8  12  24   8   8  5  2  482
# 1         7  35  35  25  24  8  2  206

# %%
df['IsMale'] = np.where(df.Sex == 'male', 1, 0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Survived    1309 non-null   int64
#  1   Pclass      1309 non-null   int64
#  2   Name        1309 non-null   object
#  3   Sex         1309 non-null   object
#  4   Age         1309 non-null   float64
#  5   SibSp       1309 non-null   int64
#  6   Parch       1309 non-null   int64
#  7   Ticket      1309 non-null   object
#  8   Fare        1309 non-null   float64
#  9   Cabin       294 non-null    object
#  10  Embarked    1309 non-null   object
#  11  Title       1309 non-null   object
#  12  Fare_bin    1309 non-null   object
#  13  AgeState    1309 non-null   object
#  14  FamilySize  1309 non-null   int64
#  15  IsMother    1309 non-null   int64
#  16  Deck        1309 non-null   object
#  17  IsMale      1309 non-null   int64
# dtypes: float64(2), int64(7), object(9)
# memory usage: 234.3+ KB

# %%
df = pd.get_dummies(df,columns=['Deck', 'Pclass','Title','Fare_bin', 'Embarked','AgeState'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 37 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Survived                                       1309 non-null   int64
#  1   Name                                           1309 non-null   object
#  2   Sex                                            1309 non-null   object
#  3   Age                                            1309 non-null   float64
#  4   SibSp                                          1309 non-null   int64
#  5   Parch                                          1309 non-null   int64
#  6   Ticket                                         1309 non-null   object
#  7   Fare                                           1309 non-null   float64
#  8   Cabin                                          294 non-null    object
#  9   FamilySize                                     1309 non-null   int64
#  10  IsMother                                       1309 non-null   int64
#  11  IsMale                                         1309 non-null   int64
#  12  Deck_A                                         1309 non-null   uint8
#  13  Deck_B                                         1309 non-null   uint8
#  14  Deck_C                                         1309 non-null   uint8
#  15  Deck_D                                         1309 non-null   uint8
#  16  Deck_E                                         1309 non-null   uint8
#  17  Deck_F                                         1309 non-null   uint8
#  18  Deck_G                                         1309 non-null   uint8
#  19  Deck_z                                         1309 non-null   uint8
#  20  Pclass_1                                       1309 non-null   uint8
#  21  Pclass_2                                       1309 non-null   uint8
#  22  Pclass_3                                       1309 non-null   uint8
#  23  Title_Lady                                     1309 non-null   uint8
#  24  Title_Major                                    1309 non-null   uint8
#  25  Title_Master                                   1309 non-null   uint8
#  26  Title_Miss                                     1309 non-null   uint8
#  27  Title_Mr                                       1309 non-null   uint8
#  28  Title_Mrs                                      1309 non-null   uint8
#  29  Title_Officer                                  1309 non-null   uint8
#  30  Title_Sir                                      1309 non-null   uint8
#  31  Fare_bin_AxesSubplot(0.125,0.125;0.775x0.755)  1309 non-null   uint8
#  32  Embarked_C                                     1309 non-null   uint8
#  33  Embarked_Q                                     1309 non-null   uint8
#  34  Embarked_S                                     1309 non-null   uint8
#  35  AgeState_Adult                                 1309 non-null   uint8
#  36  AgeState_Child                                 1309 non-null   uint8
# dtypes: float64(2), int64(6), object(4), uint8(25)
# memory usage: 204.9+ KB

# %%
df.drop(['Cabin', 'Name','Ticket','Parch','SibSp','Sex'], axis=1, inplace=True)

# %%
columns = [column for column in df.columns if column != 'Survived']
columns = columns + ['Survived']
df = df[columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 31 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            1309 non-null   float64
#  1   Fare                                           1309 non-null   float64
#  2   FamilySize                                     1309 non-null   int64
#  3   IsMother                                       1309 non-null   int64
#  4   IsMale                                         1309 non-null   int64
#  5   Deck_A                                         1309 non-null   uint8
#  6   Deck_B                                         1309 non-null   uint8
#  7   Deck_C                                         1309 non-null   uint8
#  8   Deck_D                                         1309 non-null   uint8
#  9   Deck_E                                         1309 non-null   uint8
#  10  Deck_F                                         1309 non-null   uint8
#  11  Deck_G                                         1309 non-null   uint8
#  12  Deck_z                                         1309 non-null   uint8
#  13  Pclass_1                                       1309 non-null   uint8
#  14  Pclass_2                                       1309 non-null   uint8
#  15  Pclass_3                                       1309 non-null   uint8
#  16  Title_Lady                                     1309 non-null   uint8
#  17  Title_Major                                    1309 non-null   uint8
#  18  Title_Master                                   1309 non-null   uint8
#  19  Title_Miss                                     1309 non-null   uint8
#  20  Title_Mr                                       1309 non-null   uint8
#  21  Title_Mrs                                      1309 non-null   uint8
#  22  Title_Officer                                  1309 non-null   uint8
#  23  Title_Sir                                      1309 non-null   uint8
#  24  Fare_bin_AxesSubplot(0.125,0.125;0.775x0.755)  1309 non-null   uint8
#  25  Embarked_C                                     1309 non-null   uint8
#  26  Embarked_Q                                     1309 non-null   uint8
#  27  Embarked_S                                     1309 non-null   uint8
#  28  AgeState_Adult                                 1309 non-null   uint8
#  29  AgeState_Child                                 1309 non-null   uint8
#  30  Survived                                       1309 non-null   int64
# dtypes: float64(2), int64(4), uint8(25)
# memory usage: 143.5 KB

# %%
processed_data_path = os.path.join(os.path.pardir,'data','processed')
write_train_path = os.path.join(processed_data_path,'train.csv')
write_test_path = os.path.join(processed_data_path,'test.csv')

# %%
df.loc[df.Survived != -888].to_csv(write_train_path)
columns = [column for column in df.columns if column != 'Survived']
df.loc[df.Survived == -888, columns].to_csv(write_test_path)

# %%
f, ax = plt.subplots()
ax.hist(df.Age, bins=20, color='c')
ax.set_title('Histogram: Age')
ax.set_xlabel('Bins')
ax.set_ylabel('Counts')
plt.show()

# %%
f, ax_arr = plt.subplots(3, 2, figsize = (14,10))

ax_arr[0,0].hist(df.Fare, bins=20, color='c')
ax_arr[0,0].set_title('Histogram: Fare')
ax_arr[0,0].set_xlabel('Bins')
ax_arr[0,0].set_ylabel('Counts')

ax_arr[0,1].hist(df.Age, bins=20, color='c')
ax_arr[0,1].set_title('Histogram: Age')
ax_arr[0,1].set_xlabel('Bins')
ax_arr[0,1].set_ylabel('Counts')

ax_arr[1,0].boxplot(df.Fare.values)
ax_arr[1,0].set_title('Boxplot: Age')
ax_arr[1,0].set_xlabel('Bins')
ax_arr[1,0].set_ylabel('Counts')

ax_arr[1,1].boxplot(df.Age.values)
ax_arr[1,1].set_title('Boxplot: Age')
ax_arr[1,1].set_xlabel('Bins')
ax_arr[1,1].set_ylabel('Counts')

ax_arr[2,0].scatter(df.Age, df.Fare)
ax_arr[2,0].set_title('Scatter: Age Vs Fare')
ax_arr[2,0].set_xlabel('Bins')
ax_arr[2,0].set_ylabel('Counts')

ax_arr[2,1].axis('off')
plt.tight_layout()
plt.show()

# %%
get_processed_data_script_file = os.path.join(os.path.pardir,'src','data','get_processed_data.py')

# %%
# %%writefile $get_processed_data_script_file
# import numpy as np
# import pandas as pd
# import os
#
# def read_data():
#     raw_data_path = os.path.join(os.path.pardir,'data','raw')
#     train_file_path = os.path.join(raw_data_path, 'train.csv')
#     test_file_path = os.path.join(raw_data_path, 'test.csv')
#     train_df = pd.read_csv(train_file_path, index_col='PassengerId')
#     test_df = pd.read_csv(test_file_path, index_col='PassengerId')
#     test_df['Survived'] = -888
#     df = pd.concat((train_df, test_df), axis=0)
#     return df
#
#
#
# def process_data(df):
#     return (df
#          # create title attribute - then add this
#          .assign(Title = lambda x: x.Name.map(get_title))
#          # working missing values - start with this
#          .pipe(fill_missing_values)
#          # create fare bin feature
#          .assign(Fare_Bin = lambda x: pd.qcut(x.Fare, 4, labels=['very_low','low','high','very_high']))
#          # create age state
#          .assign(AgeState = lambda x : np.where(x.Age >= 18, 'Adult','Child'))
#          .assign(FamilySize = lambda x : x.Parch + x.SibSp + 1)
#          .assign(IsMother = lambda x : np.where(((x.Sex == 'female') & (x.Parch > 0) & (x.Age > 18) & (x.Title != 'Miss')), 1, 0))
#           # create deck feature
#          .assign(Cabin = lambda x: np.where(x.Cabin == 'T', np.nan, x.Cabin))
#          .assign(Deck = lambda x : x.Cabin.map(get_deck))
#          # feature encoding
#          .assign(IsMale = lambda x : np.where(x.Sex == 'male', 1,0))
#          .pipe(pd.get_dummies, columns=['Deck', 'Pclass','Title', 'Fare_Bin', 'Embarked','AgeState'])
#          # add code to drop unnecessary columns
#          .drop(['Cabin','Name','Ticket','Parch','SibSp','Sex'], axis=1)
#          # reorder columns
#          .pipe(reorder_columns)
#          )
#
# def get_title(name):
#     title_group = {'mr' : 'Mr',
#                'mrs' : 'Mrs',
#                'miss' : 'Miss',
#                'master' : 'Master',
#                'don' : 'Sir',
#                'rev' : 'Sir',
#                'dr' : 'Officer',
#                'mme' : 'Mrs',
#                'ms' : 'Mrs',
#                'major' : 'Officer',
#                'lady' : 'Lady',
#                'sir' : 'Sir',
#                'mlle' : 'Miss',
#                'col' : 'Officer',
#                'capt' : 'Officer',
#                'the countess' : 'Lady',
#                'jonkheer' : 'Sir',
#                'dona' : 'Lady'
#                  }
#     first_name_with_title = name.split(',')[1]
#     title = first_name_with_title.split('.')[0]
#     title = title.strip().lower()
#     return title_group[title]
#
# def get_deck(cabin):
#     return np.where(pd.notnull(cabin),str(cabin)[0].upper(),'Z')
#
# def fill_missing_values(df):
#     # embarked
#     df.Embarked.fillna('C', inplace=True)
#     # fare
#     median_fare = df[(df.Pclass == 3) & (df.Embarked == 'S')]['Fare'].median()
#     df.Fare.fillna(median_fare, inplace=True)
#     # age
#     title_age_median = df.groupby('Title').Age.transform('median')
#     df.Age.fillna(title_age_median , inplace=True)
#     return df
#
# def reorder_columns(df):
#     columns = [column for column in df.columns if column != 'Survived']
#     columns = ['Survived'] + columns
#     df = df[columns]
#     return df
#
#
# def write_data(df):
#     processed_data_path = os.path.join(os.path.pardir,'data','processed')
#     write_train_path = os.path.join(processed_data_path, 'train.csv')
#     write_test_path = os.path.join(processed_data_path, 'test.csv')
#     # train data
#     df[df.Survived != -888].to_csv(write_train_path)
#     # test data
#     columns = [column for column in df.columns if column != 'Survived']
#     df[df.Survived == -888][columns].to_csv(write_test_path)
#
# if __name__ == '__main__':
#     df = read_data()
#     df = process_data(df)
#     write_data(df)
# Out:
# Overwriting ../src/data/get_processed_data.py

# %%
# !python $get_processed_data_script_file

# %%
train_df = pd.read_csv(write_train_path)
train_df.info()

test_df = pd.read_csv(write_test_path)
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 34 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   PassengerId         891 non-null    int64
#  1   Survived            891 non-null    int64
#  2   Age                 891 non-null    float64
#  3   Fare                891 non-null    float64
#  4   FamilySize          891 non-null    int64
#  5   IsMother            891 non-null    int64
#  6   IsMale              891 non-null    int64
#  7   Deck_A              891 non-null    int64
#  8   Deck_B              891 non-null    int64
#  9   Deck_C              891 non-null    int64
#  10  Deck_D              891 non-null    int64
#  11  Deck_E              891 non-null    int64
#  12  Deck_F              891 non-null    int64
#  13  Deck_G              891 non-null    int64
#  14  Deck_Z              891 non-null    int64
#  15  Pclass_1            891 non-null    int64
#  16  Pclass_2            891 non-null    int64
#  17  Pclass_3            891 non-null    int64
#  18  Title_Lady          891 non-null    int64
#  19  Title_Master        891 non-null    int64
#  20  Title_Miss          891 non-null    int64
#  21  Title_Mr            891 non-null    int64
#  22  Title_Mrs           891 non-null    int64
#  23  Title_Officer       891 non-null    int64
#  24  Title_Sir           891 non-null    int64
#  25  Fare_Bin_very_low   891 non-null    int64
#  26  Fare_Bin_low        891 non-null    int64
#  27  Fare_Bin_high       891 non-null    int64
#  28  Fare_Bin_very_high  891 non-null    int64
#  29  Embarked_C          891 non-null    int64
#  30  Embarked_Q          891 non-null    int64
#  31  Embarked_S          891 non-null    int64
#  32  AgeState_Adult      891 non-null    int64
#  33  AgeState_Child      891 non-null    int64
# dtypes: float64(2), int64(32)
# memory usage: 236.8 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 33 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   PassengerId         418 non-null    int64
#  1   Age                 418 non-null    float64
#  2   Fare                418 non-null    float64
#  3   FamilySize          418 non-null    int64
#  4   IsMother            418 non-null    int64
#  5   IsMale              418 non-null    int64
#  6   Deck_A              418 non-null    int64
#  7   Deck_B              418 non-null    int64
#  8   Deck_C              418 non-null    int64
#  9   Deck_D              418 non-null    int64
#  10  Deck_E              418 non-null    int64
#  11  Deck_F              418 non-null    int64
#  12  Deck_G              418 non-null    int64
#  13  Deck_Z              418 non-null    int64
#  14  Pclass_1            418 non-null    int64
#  15  Pclass_2            418 non-null    int64
#  16  Pclass_3            418 non-null    int64
#  17  Title_Lady          418 non-null    int64
#  18  Title_Master        418 non-null    int64
#  19  Title_Miss          418 non-null    int64
#  20  Title_Mr            418 non-null    int64
#  21  Title_Mrs           418 non-null    int64
#  22  Title_Officer       418 non-null    int64
#  23  Title_Sir           418 non-null    int64
#  24  Fare_Bin_very_low   418 non-null    int64
#  25  Fare_Bin_low        418 non-null    int64
#  26  Fare_Bin_high       418 non-null    int64
#  27  Fare_Bin_very_high  418 non-null    int64
#  28  Embarked_C          418 non-null    int64
#  29  Embarked_Q          418 non-null    int64
#  30  Embarked_S          418 non-null    int64
#  31  AgeState_Adult      418 non-null    int64
#  32  AgeState_Child      418 non-null    int64
# dtypes: float64(2), int64(31)
# memory usage: 107.9 KB
